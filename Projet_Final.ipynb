# %% [markdown]
# # Projet final du Kit Big Data 2022

# %% [markdown]
# ## Importation des librairies à utilisées

# %%
import pandas as pd
import re
import os
import shutil
import uuid
import xlwings as xw
import numpy as np

import time
import datetime
from unidecode import unidecode

import requests
from bs4 import BeautifulSoup
from urllib import request
from shutil import copyfileobj

# %% [markdown]
# ## 1. Acquisition et chargement des données

# %% [markdown]
# ### Acquisition de l'ensemble des fichiers Excel des classements et mise en place de leur copie locale

# %%
# extract list of rankings date

def List_ranking_date(url="https://www.vendeeglobe.org/fr/classement"):
    
    req = requests.get(url) # make request

    soup = BeautifulSoup(req.content) # extract content

    soup_info = soup.find('select', class_='form__input m--select onsubmit-rank') # extract specific information

    ranking_date = soup_info.find_all('option')
    list_ranking_date = [date_ranking.get('value') for date_ranking in ranking_date[1:]]
    list_ranking_date = list(set(list_ranking_date)) # Remove duplicates
    
    return list_ranking_date

list_ranking_date = List_ranking_date()
print(f"{len(list_ranking_date)} rankings dates extracted")
print(list_ranking_date[0:5])
# Out:
# 703 rankings dates extracted
# ['20201114_140000', '20210129_040000', '20210108_080000', '20201214_110000', '20210219_170000']

# %%
### Download Excel rankings data

# Define a function to download xlsx file
def Excel_rankings_data(ranking_date, excel_data_dir='', domain='https://www.vendeeglobe.org', page='/download-race-data/vendeeglobe_{date}.xlsx'):
    
    for i, ranking_date in enumerate(ranking_date):
        
        url = domain + page.format(date=ranking_date) # define url
        file = excel_data_dir + os.path.basename(page.format(date=ranking_date)) # define a destination file name and a path
                
        resp = request.urlopen(url) # get the response file object from url
        dest_file = open(file, 'wb') # Open the destination file in write mode and get the file object
        copyfileobj(resp, dest_file)  # copy the contents of response file object to destination file object
        
        #with request.urlopen(url) as response, open(filename, 'wb') as out_file:
        #copyfileobj(response, out_file)


# Create folder if does not exist 
excel_ranking_data_dir = 'data/' + 'ranking_data/'
if not os.path.exists(excel_ranking_data_dir):
        os.makedirs(excel_ranking_data_dir)

# Apply function to download Excel rankings data in directory

Excel_rankings_data(list_ranking_date, excel_data_dir=excel_ranking_data_dir)
print("Excel files upload completed.")
# Out:
# Excel files upload completed.

# %% [markdown]
# ### Chargement des données de classement juste avant les arrivées des voiliers

# %%
# reading/writing Excel file with xlwings
def save_with_xlwings(file, directory):
    tempfile = directory + '{uuid.uuid1()}.xlsx'
    excel_app = xw.App(visible=False)
    excel_book = excel_app.books.open(file)
    excel_book.save(tempfile)
    excel_book.close()
    excel_app.quit()
    return tempfile


# Function to find out if the skipper is still in the race (not arrived) or if he arrived
def skipper_status_in_race(rank):
    
    if (isinstance(rank, str)):
        if rank.strip().isnumeric():
            skipper_status = 'not arrived'   
        else:
            if 'ARV' in rank:
                skipper_status = 'arrived'
            elif 'RET' in rank:
                skipper_status = 'not arrived'
            else:
                skipper_status = np.nan            
    else:
        skipper_status = np.nan
    return skipper_status


# Function to extract rankings date and time
def ranking_date_time(data):
    
    # change name format of month
    modif_month = dict(janvier=1, fevrier=2, mars=3, avril=4, mai=5, juin=6, juillet=7, aout=8, septembre=9, octobre=10, novembre=11, decembre=12)
    
    date_time = ' '.join(data.iloc[1][1].split()[3:-1]) # extract datetime

    # separate datetime into day, month, year, time
    date_time = re.sub(' à ', ' ', date_time)
    day, month, year, fr_time = tuple(date_time.split())

    # Convert time from 15h00 to 03:00PM)
    fr_hour, fr_min = tuple(fr_time.split('h'))
    time = datetime.time(int(fr_hour), int(fr_min))

    # Convert date from 27 fevrier 2021 to 2021-02-27)
    date = datetime.datetime(int(year), modif_month[unidecode(month).lower()], int(day))
    
    date_time = datetime.datetime.combine(date, time) # obtain rankings date and time using date and time
        
    return date_time


# Function to load rankings data (from xslx files to dataframes)just before the arrival of the boats
def rankings_data(directory):
    
    rankings_data_skippers_not_arrived = pd.DataFrame()
    rankings_data_skippers_arrived = pd.DataFrame()

    xslx_files_paths = [directory+file for file in os.listdir(directory)]
    for i, file in enumerate(xslx_files_paths):
                
        # Read excel file using xlwings
        #uuid_dir = 'data/' + 'uuid/' # uuid folder
        #if not os.path.exists(uuid_dir):
         #   os.makedirs(uuid_dir)     # Create folder if not exit
        #file_uuid = save_with_xlwings(file, uuid_dir)
        rankings_data_skippers = pd.read_excel(file) #file_uuid

        # Insert ranking date
        rankings_data_skippers.insert(0, 'date_time', ranking_date_time(rankings_data_skippers))
        
        # Map skippers status (skippers arrived (finished the race), skippers not arrived (still in race or abandonned), NaN: other)
        rankings_data_skippers = rankings_data_skippers.rename(columns={'Unnamed: 0':'skipper_status'})
        rankings_data_skippers['skipper_status'] = rankings_data_skippers[list(rankings_data_skippers.columns)[2]].apply(lambda x: skipper_status_in_race(x))

        # Add skippers to dfs
        rankings_data_skippers_arrived = pd.concat([rankings_data_skippers_arrived, rankings_data_skippers[rankings_data_skippers['skipper_status'] == 'arrived']], ignore_index=True)
        rankings_data_skippers_not_arrived = pd.concat([rankings_data_skippers_not_arrived, rankings_data_skippers[rankings_data_skippers['skipper_status'] == 'not arrived']], ignore_index=True)
    
    return rankings_data_skippers_not_arrived, rankings_data_skippers_arrived


rankings_data_skippers_not_arrived, rankings_data_skippers_arrived = rankings_data(excel_ranking_data_dir)

# %%
rankings_data_skippers_not_arrived
# Out:
#                 date_time skipper_status Unnamed: 1  Unnamed: 2  \
# 0     2021-01-29 18:00:00    not arrived         10    \nFRA 53
# 1     2021-01-29 18:00:00    not arrived         11  FR\nFRA 02
# 2     2021-01-29 18:00:00    not arrived         12    \nFRA 30
# 3     2021-01-29 18:00:00    not arrived         13    \nFRA 49
# 4     2021-01-29 18:00:00    not arrived         14     \nFRA 8
# 5     2021-01-29 18:00:00    not arrived         15    \nFRA 14
# 6     2021-01-29 18:00:00    not arrived         16     \nSUI 7
# 7     2021-01-29 18:00:00    not arrived         17    \nJPN 11
# 8     2021-01-29 18:00:00    not arrived         18    \nFRA 92
# 9     2021-01-29 18:00:00    not arrived         19   \nGBR 777
# 10    2021-01-29 18:00:00    not arrived         20    \nESP 33
# 11    2021-01-29 18:00:00    not arrived         21    \nFRA 71
# 12    2021-01-29 18:00:00    not arrived         22    \nFRA 50
# 13    2021-01-29 18:00:00    not arrived         23    \nFRA 83
# 14    2021-01-29 18:00:00    not arrived         24    \nFRA 72
# 15    2021-01-29 18:00:00    not arrived         25   \nFIN 222
# 16    2021-01-29 18:00:00    not arrived        RET  FR\nFRA 69
# 17    2021-01-29 18:00:00    not arrived        RET    \nFRA 27
# 18    2021-01-29 18:00:00    not arrived        RET    \nFRA 56
# 19    2021-01-29 18:00:00    not arrived        RET   \nFRA 109
# 20    2021-01-29 18:00:00    not arrived        RET     \nFRA 4
# 21    2021-01-29 18:00:00    not arrived        RET    \nGBR 99
# 22    2021-01-29 18:00:00    not arrived        RET    \nFRA 85
# 23    2021-01-29 18:00:00    not arrived        RET     \nFRA 6
# 24    2020-11-10 10:00:00    not arrived          1     \nFRA 8
# 25    2020-11-10 10:00:00    not arrived          2    \nFRA 01
# 26    2020-11-10 10:00:00    not arrived          3  \nFRA 1000
# 27    2020-11-10 10:00:00    not arrived          4    \nFRA 09
# 28    2020-11-10 10:00:00    not arrived          5     \nFRA 6
# 29    2020-11-10 10:00:00    not arrived          6    \nFRA 53
# ...                   ...            ...        ...         ...
# 19200 2020-12-20 09:00:00    not arrived         15     \nSUI 7
# 19201 2020-12-20 09:00:00    not arrived         16    \nFRA 14
# 19202 2020-12-20 09:00:00    not arrived         17   \nGBR 777
# 19203 2020-12-20 09:00:00    not arrived         18    \nFRA 92
# 19204 2020-12-20 09:00:00    not arrived         19    \nESP 33
# 19205 2020-12-20 09:00:00    not arrived         20    \nFRA 71
# 19206 2020-12-20 09:00:00    not arrived         21     \nFRA 8
# 19207 2020-12-20 09:00:00    not arrived         22    \nJPN 11
# 19208 2020-12-20 09:00:00    not arrived         23    \nFRA 50
# 19209 2020-12-20 09:00:00    not arrived         24    \nFRA 83
# 19210 2020-12-20 09:00:00    not arrived         25    \nFRA 72
# 19211 2020-12-20 09:00:00    not arrived         26   \nFIN 222
# 19212 2020-12-20 09:00:00    not arrived         27  FR\nFRA 69
# 19213 2020-12-20 09:00:00    not arrived        RET    \nFRA 56
# 19214 2020-12-20 09:00:00    not arrived        RET   \nFRA 109
# 19215 2020-12-20 09:00:00    not arrived        RET     \nFRA 4
# 19216 2020-12-20 09:00:00    not arrived        RET    \nGBR 99
# 19217 2020-12-20 09:00:00    not arrived        RET    \nFRA 85
# 19218 2020-12-20 09:00:00    not arrived        RET     \nFRA 6
# 19219 2021-02-19 18:00:00    not arrived         23    \nFRA 71
# 19220 2021-02-19 18:00:00    not arrived         24    \nFRA 72
# 19221 2021-02-19 18:00:00    not arrived         25   \nFIN 222
# 19222 2021-02-19 18:00:00    not arrived        RET  FR\nFRA 69
# 19223 2021-02-19 18:00:00    not arrived        RET    \nFRA 27
# 19224 2021-02-19 18:00:00    not arrived        RET    \nFRA 56
# 19225 2021-02-19 18:00:00    not arrived        RET   \nFRA 109
# 19226 2021-02-19 18:00:00    not arrived        RET     \nFRA 4
# 19227 2021-02-19 18:00:00    not arrived        RET    \nGBR 99
# 19228 2021-02-19 18:00:00    not arrived        RET    \nFRA 85
# 19229 2021-02-19 18:00:00    not arrived        RET     \nFRA 6
#
#                                               Unnamed: 3  Unnamed: 4  \
# 0                          Maxime Sorel\nV And B Mayenne  17:30 FR\n
# 1                   Armel Tripon\nL'Occitane en Provence  17:30 FR\n
# 2                    Clarisse Cremer\nBanque Populaire X  17:30 FR\n
# 3      Romain Attanasio\nPure - Best Western Hotels a...  17:30 FR\n
# 4                                  Jérémie Beyou\nCharal  17:30 FR\n
# 5      Arnaud Boissieres\nLa Mie Câline - Artisans Ar...  17:30 FR\n
# 6                                Alan Roura\nLa Fabrique  17:30 FR\n
# 7                  Kojiro Shiraishi\nDMG MORI Global One  17:30 FR\n
# 8                  Stéphane Le Diraison\nTime For Oceans  17:30 FR\n
# 9                                     Pip Hare\nMedallia  17:30 FR\n
# 10                     Didac Costa\nOne Planet One Ocean  17:30 FR\n
# 11                           Manuel Cousin\nGroupe Sétin  17:30 FR\n
# 12                    Miranda Merron\nCampagne de France  17:30 FR\n
# 13             Clément Giraud\nCompagnie du lit - Jiliti  17:30 FR\n
# 14                       Alexia Barrier\nTSE - 4myplanet  17:30 FR\n
# 15                                    Ari Huusela\nStark  17:30 FR\n
# 16                            Sébastien Destremau\nMerci         NaN
# 17                               Isabelle Joschke\nMACSF         NaN
# 18             Fabrice Amedeo\nNewrest - Art et Fenetres         NaN
# 19                  Samantha Davies\nInitiatives - Coeur         NaN
# 20                         Sébastien Simon\nARKEA PAPREC         NaN
# 21                               Alex Thomson\nHUGO BOSS         NaN
# 22                                  Kevin Escoffier\nPRB         NaN
# 23                     Nicolas Troussel\nCORUM L'Épargne         NaN
# 24                                 Jérémie Beyou\nCharal  09:30 FR\n
# 25                             Jean Le Cam\nYes we Cam !  09:30 FR\n
# 26                          Damien Seguin\nGroupe APICIL  09:30 FR\n
# 27                 Benjamin Dutreux\nOMIA - Water Family  09:30 FR\n
# 28                     Nicolas Troussel\nCORUM L'Épargne  09:30 FR\n
# 29                         Maxime Sorel\nV And B Mayenne  09:30 FR\n
# ...                                                  ...         ...
# 19200                            Alan Roura\nLa Fabrique  08:30 FR\n
# 19201  Arnaud Boissieres\nLa Mie Câline - Artisans Ar...  08:30 FR\n
# 19202                                 Pip Hare\nMedallia  08:30 FR\n
# 19203              Stéphane Le Diraison\nTime For Oceans  08:30 FR\n
# 19204                  Didac Costa\nOne Planet One Ocean  08:30 FR\n
# 19205                        Manuel Cousin\nGroupe Sétin  08:30 FR\n
# 19206                              Jérémie Beyou\nCharal  08:30 FR\n
# 19207              Kojiro Shiraishi\nDMG MORI Global One  08:30 FR\n
# 19208                 Miranda Merron\nCampagne de France  08:30 FR\n
# 19209          Clément Giraud\nCompagnie du lit - Jiliti  08:30 FR\n
# 19210                    Alexia Barrier\nTSE - 4myplanet  08:30 FR\n
# 19211                                 Ari Huusela\nStark  08:30 FR\n
# 19212                         Sébastien Destremau\nMerci  08:30 FR\n
# 19213          Fabrice Amedeo\nNewrest - Art et Fenetres         NaN
# 19214               Samantha Davies\nInitiatives - Coeur         NaN
# 19215                      Sébastien Simon\nARKEA PAPREC         NaN
# 19216                            Alex Thomson\nHUGO BOSS         NaN
# 19217                               Kevin Escoffier\nPRB         NaN
# 19218                  Nicolas Troussel\nCORUM L'Épargne         NaN
# 19219                        Manuel Cousin\nGroupe Sétin  17:30 FR\n
# 19220                    Alexia Barrier\nTSE - 4myplanet  17:30 FR\n
# 19221                                 Ari Huusela\nStark  17:30 FR\n
# 19222                         Sébastien Destremau\nMerci         NaN
# 19223                            Isabelle Joschke\nMACSF         NaN
# 19224          Fabrice Amedeo\nNewrest - Art et Fenetres         NaN
# 19225               Samantha Davies\nInitiatives - Coeur         NaN
# 19226                      Sébastien Simon\nARKEA PAPREC         NaN
# 19227                            Alex Thomson\nHUGO BOSS         NaN
# 19228                               Kevin Escoffier\nPRB         NaN
# 19229                  Nicolas Troussel\nCORUM L'Épargne         NaN
#
#        Unnamed: 5   Unnamed: 6 Unnamed: 7 Unnamed: 8  ... Unnamed: 11  \
# 0      46°07.29'N   06°13.58'W        82°   19.1 kts  ...         72°
# 1      41°40.31'N   10°38.49'W         5°    8.5 kts  ...         17°
# 2      36°26.28'N   29°36.29'W       353°    8.1 kts  ...          9°
# 3      23°59.68'N   34°28.19'W        14°   10.4 kts  ...         18°
# 4      22°51.11'N   36°30.29'W         9°   16.6 kts  ...          2°
# 5      10°51.53'N   35°18.82'W       334°   15.8 kts  ...        339°
# 6      07°39.50'N   34°49.21'W       340°   12.7 kts  ...        336°
# 7      07°11.91'N   34°29.06'W       331°   15.1 kts  ...        335°
# 8      06°30.68'N   34°23.16'W       337°   12.6 kts  ...        343°
# 9      04°51.03'N   34°32.62'W       336°   11.1 kts  ...        341°
# 10     02°46.13'N   32°42.56'W       359°    6.5 kts  ...        349°
# 11     15°05.63'S   29°19.03'W       353°   13.8 kts  ...        348°
# 12     17°38.02'S   28°37.16'W       346°    9.8 kts  ...        342°
# 13     19°03.91'S   31°20.79'W        16°    9.8 kts  ...        353°
# 14     41°12.38'S   45°51.32'W        57°   10.6 kts  ...         55°
# 15     42°31.12'S   44°38.02'W        57°    9.3 kts  ...         57°
# 16            NaN          NaN        NaN        NaN  ...         NaN
# 17            NaN          NaN        NaN        NaN  ...         NaN
# 18            NaN          NaN        NaN        NaN  ...         NaN
# 19            NaN          NaN        NaN        NaN  ...         NaN
# 20            NaN          NaN        NaN        NaN  ...         NaN
# 21            NaN          NaN        NaN        NaN  ...         NaN
# 22            NaN          NaN        NaN        NaN  ...         NaN
# 23            NaN          NaN        NaN        NaN  ...         NaN
# 24     43°28.72'N   10°31.39'W       270°    9.5 kts  ...        255°
# 25     43°10.90'N   09°20.59'W       231°    8.2 kts  ...        215°
# 26     43°11.81'N   09°14.41'W       246°    3.2 kts  ...        233°
# 27     43°12.68'N   09°15.17'W       240°    8.1 kts  ...        215°
# 28     43°13.67'N   09°16.68'W       234°    4.4 kts  ...        148°
# 29     43°14.58'N   09°17.24'W       226°    6.8 kts  ...        207°
# ...           ...          ...        ...        ...  ...         ...
# 19200  44°56.96'S  109°20.52'E       134°   14.6 kts  ...        129°
# 19201  45°28.53'S  100°39.16'E        72°   15.6 kts  ...         71°
# 19202  45°56.11'S   97°24.06'E        86°   16.0 kts  ...         88°
# 19203  44°27.56'S   97°31.18'E        83°   16.0 kts  ...         83°
# 19204  45°11.59'S   95°01.72'E        91°   14.4 kts  ...         92°
# 19205  45°06.81'S   91°34.12'E        91°   14.9 kts  ...         90°
# 19206  44°07.41'S   86°07.88'E        96°   21.0 kts  ...         98°
# 19207  43°54.76'S   82°06.25'E        96°   18.7 kts  ...        100°
# 19208  43°17.58'S   75°54.24'E       101°    7.7 kts  ...         78°
# 19209  44°13.42'S   74°13.52'E       121°   10.8 kts  ...        124°
# 19210  43°45.30'S   73°45.94'E       109°   11.3 kts  ...        113°
# 19211  43°04.52'S   63°47.69'E        52°    7.2 kts  ...        112°
# 19212  40°06.31'S   56°21.99'E        69°    8.8 kts  ...         85°
# 19213         NaN          NaN        NaN        NaN  ...         NaN
# 19214         NaN          NaN        NaN        NaN  ...         NaN
# 19215         NaN          NaN        NaN        NaN  ...         NaN
# 19216         NaN          NaN        NaN        NaN  ...         NaN
# 19217         NaN          NaN        NaN        NaN  ...         NaN
# 19218         NaN          NaN        NaN        NaN  ...         NaN
# 19219  45°17.53'N   05°18.09'W        65°   10.2 kts  ...         62°
# 19220  27°31.62'N   34°39.97'W        36°   11.7 kts  ...         37°
# 19221  21°51.43'N   36°12.21'W       332°    7.3 kts  ...        339°
# 19222         NaN          NaN        NaN        NaN  ...         NaN
# 19223         NaN          NaN        NaN        NaN  ...         NaN
# 19224         NaN          NaN        NaN        NaN  ...         NaN
# 19225         NaN          NaN        NaN        NaN  ...         NaN
# 19226         NaN          NaN        NaN        NaN  ...         NaN
# 19227         NaN          NaN        NaN        NaN  ...         NaN
# 19228         NaN          NaN        NaN        NaN  ...         NaN
# 19229         NaN          NaN        NaN        NaN  ...         NaN
#
#       Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17  \
# 0        15.1 kts    15.0 kts     45.3 nm         49°    12.4 kts    12.3 kts
# 1         7.5 kts     7.3 kts     22.4 nm         62°     7.3 kts     7.1 kts
# 2         8.7 kts     6.1 kts     26.2 nm         10°    11.9 kts     9.3 kts
# 3        10.8 kts    10.0 kts     32.5 nm         11°    11.3 kts    10.2 kts
# 4        15.2 kts    12.0 kts     45.6 nm        356°    16.7 kts    12.9 kts
# 5        15.6 kts     9.8 kts     46.8 nm        337°    12.5 kts     8.2 kts
# 6        13.2 kts     8.4 kts     39.5 nm        330°    11.8 kts     7.2 kts
# 7        16.0 kts    10.0 kts     48.1 nm        330°    12.0 kts     7.5 kts
# 8        13.4 kts     9.9 kts     40.3 nm        339°    10.1 kts     7.4 kts
# 9        11.0 kts     7.9 kts     32.9 nm        343°     7.6 kts     5.8 kts
# 10        5.1 kts     4.3 kts     15.4 nm          1°     9.2 kts     8.6 kts
# 11       13.7 kts    12.4 kts     41.0 nm        345°    12.5 kts    11.2 kts
# 12       10.8 kts     9.4 kts     32.5 nm        344°    10.4 kts     9.3 kts
# 13        9.7 kts     9.0 kts     29.2 nm        354°     8.3 kts     7.8 kts
# 14       10.2 kts     8.8 kts     30.6 nm         38°    11.1 kts    10.9 kts
# 15        9.6 kts     8.0 kts     28.9 nm         47°    11.6 kts    10.8 kts
# 16            NaN         NaN         NaN         NaN         NaN         NaN
# 17            NaN         NaN         NaN         NaN         NaN         NaN
# 18            NaN         NaN         NaN         NaN         NaN         NaN
# 19            NaN         NaN         NaN         NaN         NaN         NaN
# 20            NaN         NaN         NaN         NaN         NaN         NaN
# 21            NaN         NaN         NaN         NaN         NaN         NaN
# 22            NaN         NaN         NaN         NaN         NaN         NaN
# 23            NaN         NaN         NaN         NaN         NaN         NaN
# 24        7.5 kts     4.5 kts     30.1 nm        202°     9.2 kts     9.2 kts
# 25        5.6 kts     5.5 kts     22.6 nm        212°     7.8 kts     7.7 kts
# 26        6.6 kts     5.7 kts     26.4 nm        209°     7.8 kts     7.7 kts
# 27        6.2 kts     6.1 kts     24.9 nm        205°     8.4 kts     8.4 kts
# 28        6.2 kts     3.6 kts     24.8 nm        187°     9.0 kts     8.7 kts
# 29        5.5 kts     5.5 kts     22.2 nm        209°     7.6 kts     7.6 kts
# ...           ...         ...         ...         ...         ...         ...
# 19200    14.0 kts    12.8 kts     55.9 nm        104°    13.9 kts    13.9 kts
# 19201    16.1 kts    14.7 kts     64.6 nm         97°    11.7 kts    11.7 kts
# 19202    16.6 kts    16.5 kts     66.4 nm         87°    16.3 kts    16.1 kts
# 19203    16.0 kts    15.1 kts     64.1 nm         85°    13.5 kts    12.8 kts
# 19204    14.8 kts    14.7 kts     59.3 nm         91°    14.4 kts    14.1 kts
# 19205    15.6 kts    15.3 kts     62.3 nm         92°    13.6 kts    13.3 kts
# 19206    20.4 kts    20.3 kts     81.8 nm         91°    17.9 kts    17.2 kts
# 19207    17.3 kts    17.2 kts     69.2 nm         96°    16.9 kts    16.5 kts
# 19208    10.5 kts     9.2 kts     42.1 nm         92°    12.9 kts    12.3 kts
# 19209    12.3 kts    11.8 kts     49.3 nm        105°    12.1 kts    12.0 kts
# 19210    12.0 kts    11.9 kts     47.9 nm        100°    12.0 kts    11.8 kts
# 19211    10.2 kts    10.2 kts     40.9 nm         86°    11.0 kts    10.0 kts
# 19212     6.1 kts     5.2 kts     27.3 nm         85°     7.4 kts     6.2 kts
# 19213         NaN         NaN         NaN         NaN         NaN         NaN
# 19214         NaN         NaN         NaN         NaN         NaN         NaN
# 19215         NaN         NaN         NaN         NaN         NaN         NaN
# 19216         NaN         NaN         NaN         NaN         NaN         NaN
# 19217         NaN         NaN         NaN         NaN         NaN         NaN
# 19218         NaN         NaN         NaN         NaN         NaN         NaN
# 19219    11.0 kts    11.0 kts     33.0 nm         52°    10.1 kts    10.1 kts
# 19220    11.0 kts    10.9 kts     33.1 nm         35°     6.8 kts     6.7 kts
# 19221     7.0 kts     3.4 kts     21.1 nm        340°     8.8 kts     5.0 kts
# 19222         NaN         NaN         NaN         NaN         NaN         NaN
# 19223         NaN         NaN         NaN         NaN         NaN         NaN
# 19224         NaN         NaN         NaN         NaN         NaN         NaN
# 19225         NaN         NaN         NaN         NaN         NaN         NaN
# 19226         NaN         NaN         NaN         NaN         NaN         NaN
# 19227         NaN         NaN         NaN         NaN         NaN         NaN
# 19228         NaN         NaN         NaN         NaN         NaN         NaN
# 19229         NaN         NaN         NaN         NaN         NaN         NaN
#
#       Unnamed: 18 Unnamed: 19 Unnamed: 20
# 0        298.4 nm    185.1 nm      0.0 nm
# 1        175.1 nm    482.6 nm    297.5 nm
# 2        285.5 nm   1379.1 nm   1194.0 nm
# 3        271.9 nm   2069.2 nm   1884.1 nm
# 4        400.0 nm   2194.6 nm   2009.5 nm
# 5        300.3 nm   2741.5 nm   2556.4 nm
# 6        282.7 nm   2895.6 nm   2710.4 nm
# 7        288.6 nm   2911.1 nm   2725.9 nm
# 8        241.5 nm   2945.4 nm   2760.2 nm
# 9        182.3 nm   3039.3 nm   2854.1 nm
# 10       219.7 nm   3109.4 nm   2924.3 nm
# 11       299.2 nm   4073.7 nm   3888.5 nm
# 12       249.1 nm   4213.6 nm   4028.5 nm
# 13       198.8 nm   4333.0 nm   4147.9 nm
# 14       266.5 nm   5830.1 nm   5645.0 nm
# 15       278.1 nm   5881.1 nm   5696.0 nm
# 16            NaN         NaN         NaN
# 17            NaN         NaN         NaN
# 18            NaN         NaN         NaN
# 19            NaN         NaN         NaN
# 20            NaN         NaN         NaN
# 21            NaN         NaN         NaN
# 22            NaN         NaN         NaN
# 23            NaN         NaN         NaN
# 24       221.7 nm  23921.1 nm      0.0 nm
# 25       186.3 nm  23923.3 nm      2.2 nm
# 26       186.3 nm  23925.8 nm      4.8 nm
# 27       201.5 nm  23926.4 nm      5.4 nm
# 28       211.0 nm  23926.9 nm      5.9 nm
# 29       183.2 nm  23927.6 nm      6.6 nm
# ...           ...         ...         ...
# 19200    334.8 nm  13559.9 nm   2620.3 nm
# 19201    281.1 nm  13916.9 nm   2977.3 nm
# 19202    392.1 nm  14049.7 nm   3110.1 nm
# 19203    323.1 nm  14059.0 nm   3119.4 nm
# 19204    344.4 nm  14154.0 nm   3214.4 nm
# 19205    325.9 nm  14299.1 nm   3359.5 nm
# 19206    429.6 nm  14538.8 nm   3599.2 nm
# 19207    405.5 nm  14710.0 nm   3770.4 nm
# 19208    309.0 nm  14979.0 nm   4039.4 nm
# 19209    290.1 nm  15032.8 nm   4093.2 nm
# 19210    288.8 nm  15059.8 nm   4120.1 nm
# 19211    264.3 nm  15485.0 nm   4545.4 nm
# 19212    176.7 nm  15861.7 nm   4922.0 nm
# 19213         NaN         NaN         NaN
# 19214         NaN         NaN         NaN
# 19215         NaN         NaN         NaN
# 19216         NaN         NaN         NaN
# 19217         NaN         NaN         NaN
# 19218         NaN         NaN         NaN
# 19219    241.8 nm    162.6 nm      0.0 nm
# 19220    163.5 nm   1921.2 nm   1758.5 nm
# 19221    211.0 nm   2229.0 nm   2066.4 nm
# 19222         NaN         NaN         NaN
# 19223         NaN         NaN         NaN
# 19224         NaN         NaN         NaN
# 19225         NaN         NaN         NaN
# 19226         NaN         NaN         NaN
# 19227         NaN         NaN         NaN
# 19228         NaN         NaN         NaN
# 19229         NaN         NaN         NaN
#
# [19230 rows x 22 columns]

# %%
rankings_data_skippers_arrived
# Out:
#                date_time skipper_status Unnamed: 1  Unnamed: 2  \
# 0    2021-01-29 18:00:00        arrived     1\nARV    \nFRA 17
# 1    2021-01-29 18:00:00        arrived     2\nARV    \nFRA 79
# 2    2021-01-29 18:00:00        arrived     3\nARV    \nFRA 18
# 3    2021-01-29 18:00:00        arrived     4\nARV    \nFRA 01
# 4    2021-01-29 18:00:00        arrived     5\nARV    \nMON 10
# 5    2021-01-29 18:00:00        arrived     6\nARV    \nFRA 59
# 6    2021-01-29 18:00:00        arrived     7\nARV  \nFRA 1000
# 7    2021-01-29 18:00:00        arrived     8\nARV    \nITA 34
# 8    2021-01-29 18:00:00        arrived     9\nARV    \nFRA 09
# 9    2021-02-02 18:00:00        arrived     1\nARV    \nFRA 17
# 10   2021-02-02 18:00:00        arrived     2\nARV    \nFRA 79
# 11   2021-02-02 18:00:00        arrived     3\nARV    \nFRA 18
# 12   2021-02-02 18:00:00        arrived     4\nARV    \nFRA 01
# 13   2021-02-02 18:00:00        arrived     5\nARV    \nMON 10
# 14   2021-02-02 18:00:00        arrived     6\nARV    \nFRA 59
# 15   2021-02-02 18:00:00        arrived     7\nARV  \nFRA 1000
# 16   2021-02-02 18:00:00        arrived     8\nARV    \nITA 34
# 17   2021-02-02 18:00:00        arrived     9\nARV    \nFRA 09
# 18   2021-02-02 18:00:00        arrived    10\nARV    \nFRA 53
# 19   2021-02-02 18:00:00        arrived    11\nARV  FR\nFRA 02
# 20   2021-02-14 12:00:00        arrived     1\nARV    \nFRA 17
# 21   2021-02-14 12:00:00        arrived     2\nARV    \nFRA 79
# 22   2021-02-14 12:00:00        arrived     3\nARV    \nFRA 18
# 23   2021-02-14 12:00:00        arrived     4\nARV    \nFRA 01
# 24   2021-02-14 12:00:00        arrived     5\nARV    \nMON 10
# 25   2021-02-14 12:00:00        arrived     6\nARV    \nFRA 59
# 26   2021-02-14 12:00:00        arrived     7\nARV  \nFRA 1000
# 27   2021-02-14 12:00:00        arrived     8\nARV    \nITA 34
# 28   2021-02-14 12:00:00        arrived     9\nARV    \nFRA 09
# 29   2021-02-14 12:00:00        arrived    10\nARV    \nFRA 53
# ...                  ...            ...        ...         ...
# 3901 2021-02-01 09:00:00        arrived     4\nARV    \nFRA 01
# 3902 2021-02-01 09:00:00        arrived     5\nARV    \nMON 10
# 3903 2021-02-01 09:00:00        arrived     6\nARV    \nFRA 59
# 3904 2021-02-01 09:00:00        arrived     7\nARV  \nFRA 1000
# 3905 2021-02-01 09:00:00        arrived     8\nARV    \nITA 34
# 3906 2021-02-01 09:00:00        arrived     9\nARV    \nFRA 09
# 3907 2021-02-01 09:00:00        arrived    10\nARV    \nFRA 53
# 3908 2021-02-01 09:00:00        arrived    11\nARV  FR\nFRA 02
# 3909 2021-02-19 18:00:00        arrived     1\nARV    \nFRA 17
# 3910 2021-02-19 18:00:00        arrived     2\nARV    \nFRA 79
# 3911 2021-02-19 18:00:00        arrived     3\nARV    \nFRA 18
# 3912 2021-02-19 18:00:00        arrived     4\nARV    \nFRA 01
# 3913 2021-02-19 18:00:00        arrived     5\nARV    \nMON 10
# 3914 2021-02-19 18:00:00        arrived     6\nARV    \nFRA 59
# 3915 2021-02-19 18:00:00        arrived     7\nARV  \nFRA 1000
# 3916 2021-02-19 18:00:00        arrived     8\nARV    \nITA 34
# 3917 2021-02-19 18:00:00        arrived     9\nARV    \nFRA 09
# 3918 2021-02-19 18:00:00        arrived    10\nARV    \nFRA 53
# 3919 2021-02-19 18:00:00        arrived    11\nARV  FR\nFRA 02
# 3920 2021-02-19 18:00:00        arrived    12\nARV    \nFRA 30
# 3921 2021-02-19 18:00:00        arrived    13\nARV     \nFRA 8
# 3922 2021-02-19 18:00:00        arrived    14\nARV    \nFRA 49
# 3923 2021-02-19 18:00:00        arrived    15\nARV    \nFRA 14
# 3924 2021-02-19 18:00:00        arrived    16\nARV    \nJPN 11
# 3925 2021-02-19 18:00:00        arrived    17\nARV     \nSUI 7
# 3926 2021-02-19 18:00:00        arrived    18\nARV    \nFRA 92
# 3927 2021-02-19 18:00:00        arrived    19\nARV   \nGBR 777
# 3928 2021-02-19 18:00:00        arrived    20\nARV    \nESP 33
# 3929 2021-02-19 18:00:00        arrived    21\nARV    \nFRA 83
# 3930 2021-02-19 18:00:00        arrived    22\nARV    \nFRA 50
#
#                                              Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                       Yannick Bestaven\nMaître Coq IV        NaN        NaN
# 1                                 Charlie Dalin\nAPIVIA        NaN        NaN
# 2                         Louis Burton\nBureau Vallée 2        NaN        NaN
# 3                             Jean Le Cam\nYes we Cam !        NaN        NaN
# 4     Boris Herrmann\nSeaexplorer - Yacht Club De Mo...        NaN        NaN
# 5                              Thomas Ruyant\nLinkedOut        NaN        NaN
# 6                          Damien Seguin\nGroupe APICIL        NaN        NaN
# 7                      Giancarlo Pedote\nPrysmian Group        NaN        NaN
# 8                 Benjamin Dutreux\nOMIA - Water Family        NaN        NaN
# 9                       Yannick Bestaven\nMaître Coq IV        NaN        NaN
# 10                                Charlie Dalin\nAPIVIA        NaN        NaN
# 11                        Louis Burton\nBureau Vallée 2        NaN        NaN
# 12                            Jean Le Cam\nYes we Cam !        NaN        NaN
# 13    Boris Herrmann\nSeaexplorer - Yacht Club De Mo...        NaN        NaN
# 14                             Thomas Ruyant\nLinkedOut        NaN        NaN
# 15                         Damien Seguin\nGroupe APICIL        NaN        NaN
# 16                     Giancarlo Pedote\nPrysmian Group        NaN        NaN
# 17                Benjamin Dutreux\nOMIA - Water Family        NaN        NaN
# 18                        Maxime Sorel\nV And B Mayenne        NaN        NaN
# 19                 Armel Tripon\nL'Occitane en Provence        NaN        NaN
# 20                      Yannick Bestaven\nMaître Coq IV        NaN        NaN
# 21                                Charlie Dalin\nAPIVIA        NaN        NaN
# 22                        Louis Burton\nBureau Vallée 2        NaN        NaN
# 23                            Jean Le Cam\nYes we Cam !        NaN        NaN
# 24    Boris Herrmann\nSeaexplorer - Yacht Club De Mo...        NaN        NaN
# 25                             Thomas Ruyant\nLinkedOut        NaN        NaN
# 26                         Damien Seguin\nGroupe APICIL        NaN        NaN
# 27                     Giancarlo Pedote\nPrysmian Group        NaN        NaN
# 28                Benjamin Dutreux\nOMIA - Water Family        NaN        NaN
# 29                        Maxime Sorel\nV And B Mayenne        NaN        NaN
# ...                                                 ...        ...        ...
# 3901                          Jean Le Cam\nYes we Cam !        NaN        NaN
# 3902  Boris Herrmann\nSeaexplorer - Yacht Club De Mo...        NaN        NaN
# 3903                           Thomas Ruyant\nLinkedOut        NaN        NaN
# 3904                       Damien Seguin\nGroupe APICIL        NaN        NaN
# 3905                   Giancarlo Pedote\nPrysmian Group        NaN        NaN
# 3906              Benjamin Dutreux\nOMIA - Water Family        NaN        NaN
# 3907                      Maxime Sorel\nV And B Mayenne        NaN        NaN
# 3908               Armel Tripon\nL'Occitane en Provence        NaN        NaN
# 3909                    Yannick Bestaven\nMaître Coq IV        NaN        NaN
# 3910                              Charlie Dalin\nAPIVIA        NaN        NaN
# 3911                      Louis Burton\nBureau Vallée 2        NaN        NaN
# 3912                          Jean Le Cam\nYes we Cam !        NaN        NaN
# 3913  Boris Herrmann\nSeaexplorer - Yacht Club De Mo...        NaN        NaN
# 3914                           Thomas Ruyant\nLinkedOut        NaN        NaN
# 3915                       Damien Seguin\nGroupe APICIL        NaN        NaN
# 3916                   Giancarlo Pedote\nPrysmian Group        NaN        NaN
# 3917              Benjamin Dutreux\nOMIA - Water Family        NaN        NaN
# 3918                      Maxime Sorel\nV And B Mayenne        NaN        NaN
# 3919               Armel Tripon\nL'Occitane en Provence        NaN        NaN
# 3920                Clarisse Cremer\nBanque Populaire X        NaN        NaN
# 3921                              Jérémie Beyou\nCharal        NaN        NaN
# 3922  Romain Attanasio\nPure - Best Western Hotels a...        NaN        NaN
# 3923  Arnaud Boissieres\nLa Mie Câline - Artisans Ar...        NaN        NaN
# 3924              Kojiro Shiraishi\nDMG MORI Global One        NaN        NaN
# 3925                            Alan Roura\nLa Fabrique        NaN        NaN
# 3926              Stéphane Le Diraison\nTime For Oceans        NaN        NaN
# 3927                                 Pip Hare\nMedallia        NaN        NaN
# 3928                  Didac Costa\nOne Planet One Ocean        NaN        NaN
# 3929          Clément Giraud\nCompagnie du lit - Jiliti        NaN        NaN
# 3930                 Miranda Merron\nCampagne de France        NaN        NaN
#
#      Unnamed: 6              Unnamed: 7                         Unnamed: 8  \
# 0           NaN  28/01/2021 04:19:46 FR  80j 03h 44min 46s\n-10h 15min 00s
# 1           NaN  27/01/2021 20:35:47 FR                80j 06h 15min 47s\n
# 2           NaN  28/01/2021 00:45:12 FR                80j 10h 25min 12s\n
# 3           NaN  28/01/2021 20:19:55 FR  80j 13h 44min 55s\n-16h 15min 00s
# 4           NaN  28/01/2021 11:19:45 FR  80j 14h 59min 45s\n-06h 00min 00s
# 5           NaN  28/01/2021 05:42:01 FR                80j 15h 22min 01s\n
# 6           NaN  28/01/2021 12:18:20 FR                80j 21h 58min 20s\n
# 7           NaN  28/01/2021 13:02:20 FR                80j 22h 42min 20s\n
# 8           NaN  29/01/2021 10:05:20 FR                81j 19h 45min 20s\n
# 9           NaN  28/01/2021 04:19:46 FR  80j 03h 44min 46s\n-10h 15min 00s
# 10          NaN  27/01/2021 20:35:47 FR                80j 06h 15min 47s\n
# 11          NaN  28/01/2021 00:45:12 FR                80j 10h 25min 12s\n
# 12          NaN  28/01/2021 20:19:55 FR  80j 13h 44min 55s\n-16h 15min 00s
# 13          NaN  28/01/2021 11:19:45 FR  80j 14h 59min 45s\n-06h 00min 00s
# 14          NaN  28/01/2021 05:42:01 FR                80j 15h 22min 01s\n
# 15          NaN  28/01/2021 12:18:20 FR                80j 21h 58min 20s\n
# 16          NaN  28/01/2021 13:02:20 FR                80j 22h 42min 20s\n
# 17          NaN  29/01/2021 10:05:20 FR                81j 19h 45min 20s\n
# 18          NaN  30/01/2021 04:50:15 FR                82j 14h 30min 15s\n
# 19          NaN  01/02/2021 07:27:50 FR                84j 17h 07min 50s\n
# 20          NaN  28/01/2021 04:19:46 FR  80j 03h 44min 46s\n-10h 15min 00s
# 21          NaN  27/01/2021 20:35:47 FR                80j 06h 15min 47s\n
# 22          NaN  28/01/2021 00:45:12 FR                80j 10h 25min 12s\n
# 23          NaN  28/01/2021 20:19:55 FR  80j 13h 44min 55s\n-16h 15min 00s
# 24          NaN  28/01/2021 11:19:45 FR  80j 14h 59min 45s\n-06h 00min 00s
# 25          NaN  28/01/2021 05:42:01 FR                80j 15h 22min 01s\n
# 26          NaN  28/01/2021 12:18:20 FR                80j 21h 58min 20s\n
# 27          NaN  28/01/2021 13:02:20 FR                80j 22h 42min 20s\n
# 28          NaN  29/01/2021 10:05:20 FR                81j 19h 45min 20s\n
# 29          NaN  30/01/2021 04:50:15 FR                82j 14h 30min 15s\n
# ...         ...                     ...                                ...
# 3901        NaN  28/01/2021 20:19:55 FR  80j 13h 44min 55s\n-16h 15min 00s
# 3902        NaN  28/01/2021 11:19:45 FR  80j 14h 59min 45s\n-06h 00min 00s
# 3903        NaN  28/01/2021 05:42:01 FR                80j 15h 22min 01s\n
# 3904        NaN  28/01/2021 12:18:20 FR                80j 21h 58min 20s\n
# 3905        NaN  28/01/2021 13:02:20 FR                80j 22h 42min 20s\n
# 3906        NaN  29/01/2021 10:05:20 FR                81j 19h 45min 20s\n
# 3907        NaN  30/01/2021 04:50:15 FR                82j 14h 30min 15s\n
# 3908        NaN  01/02/2021 07:27:50 FR                84j 17h 07min 50s\n
# 3909        NaN  28/01/2021 04:19:46 FR  80j 03h 44min 46s\n-10h 15min 00s
# 3910        NaN  27/01/2021 20:35:47 FR                80j 06h 15min 47s\n
# 3911        NaN  28/01/2021 00:45:12 FR                80j 10h 25min 12s\n
# 3912        NaN  28/01/2021 20:19:55 FR  80j 13h 44min 55s\n-16h 15min 00s
# 3913        NaN  28/01/2021 11:19:45 FR  80j 14h 59min 45s\n-06h 00min 00s
# 3914        NaN  28/01/2021 05:42:01 FR                80j 15h 22min 01s\n
# 3915        NaN  28/01/2021 12:18:20 FR                80j 21h 58min 20s\n
# 3916        NaN  28/01/2021 13:02:20 FR                80j 22h 42min 20s\n
# 3917        NaN  29/01/2021 10:05:20 FR                81j 19h 45min 20s\n
# 3918        NaN  30/01/2021 04:50:15 FR                82j 14h 30min 15s\n
# 3919        NaN  01/02/2021 07:27:50 FR  84j 19h 07min 50s\n+02h 00min 00s
# 3920        NaN  03/02/2021 16:44:25 FR                87j 02h 24min 25s\n
# 3921        NaN  06/02/2021 09:15:58 FR                89j 18h 55min 58s\n
# 3922        NaN  06/02/2021 17:06:02 FR                90j 02h 46min 02s\n
# 3923        NaN  11/02/2021 08:56:06 FR                94j 18h 36min 06s\n
# 3924        NaN  11/02/2021 11:52:56 FR                94j 21h 32min 56s\n
# 3925        NaN  11/02/2021 20:29:56 FR                95j 06h 09min 56s\n
# 3926        NaN  11/02/2021 22:36:00 FR                95j 08h 16min 00s\n
# 3927        NaN  12/02/2021 01:57:30 FR                95j 11h 37min 30s\n
# 3928        NaN  13/02/2021 20:47:03 FR                97j 06h 27min 03s\n
# 3929        NaN  16/02/2021 10:28:31 FR                99j 20h 08min 31s\n
# 3930        NaN  17/02/2021 23:16:51 FR               101j 08h 56min 51s\n
#
#       ... Unnamed: 11 Unnamed: 12        Unnamed: 13 Unnamed: 14  \
# 0     ...         NaN         NaN                NaN         NaN
# 1     ...         NaN         NaN      02h 31min 01s         NaN
# 2     ...         NaN         NaN      06h 40min 26s         NaN
# 3     ...         NaN         NaN      10h 00min 09s         NaN
# 4     ...         NaN         NaN      11h 14min 59s         NaN
# 5     ...         NaN         NaN      11h 37min 15s         NaN
# 6     ...         NaN         NaN      18h 13min 34s         NaN
# 7     ...         NaN         NaN      18h 57min 34s         NaN
# 8     ...         NaN         NaN   1j 16h 00min 34s         NaN
# 9     ...         NaN         NaN                NaN         NaN
# 10    ...         NaN         NaN      02h 31min 01s         NaN
# 11    ...         NaN         NaN      06h 40min 26s         NaN
# 12    ...         NaN         NaN      10h 00min 09s         NaN
# 13    ...         NaN         NaN      11h 14min 59s         NaN
# 14    ...         NaN         NaN      11h 37min 15s         NaN
# 15    ...         NaN         NaN      18h 13min 34s         NaN
# 16    ...         NaN         NaN      18h 57min 34s         NaN
# 17    ...         NaN         NaN   1j 16h 00min 34s         NaN
# 18    ...         NaN         NaN   2j 10h 45min 29s         NaN
# 19    ...         NaN         NaN   4j 13h 23min 04s         NaN
# 20    ...         NaN         NaN                NaN         NaN
# 21    ...         NaN         NaN      02h 31min 01s         NaN
# 22    ...         NaN         NaN      06h 40min 26s         NaN
# 23    ...         NaN         NaN      10h 00min 09s         NaN
# 24    ...         NaN         NaN      11h 14min 59s         NaN
# 25    ...         NaN         NaN      11h 37min 15s         NaN
# 26    ...         NaN         NaN      18h 13min 34s         NaN
# 27    ...         NaN         NaN      18h 57min 34s         NaN
# 28    ...         NaN         NaN   1j 16h 00min 34s         NaN
# 29    ...         NaN         NaN   2j 10h 45min 29s         NaN
# ...   ...         ...         ...                ...         ...
# 3901  ...         NaN         NaN      10h 00min 09s         NaN
# 3902  ...         NaN         NaN      11h 14min 59s         NaN
# 3903  ...         NaN         NaN      11h 37min 15s         NaN
# 3904  ...         NaN         NaN      18h 13min 34s         NaN
# 3905  ...         NaN         NaN      18h 57min 34s         NaN
# 3906  ...         NaN         NaN   1j 16h 00min 34s         NaN
# 3907  ...         NaN         NaN   2j 10h 45min 29s         NaN
# 3908  ...         NaN         NaN   4j 13h 23min 04s         NaN
# 3909  ...         NaN         NaN                NaN         NaN
# 3910  ...         NaN         NaN      02h 31min 01s         NaN
# 3911  ...         NaN         NaN      06h 40min 26s         NaN
# 3912  ...         NaN         NaN      10h 00min 09s         NaN
# 3913  ...         NaN         NaN      11h 14min 59s         NaN
# 3914  ...         NaN         NaN      11h 37min 15s         NaN
# 3915  ...         NaN         NaN      18h 13min 34s         NaN
# 3916  ...         NaN         NaN      18h 57min 34s         NaN
# 3917  ...         NaN         NaN   1j 16h 00min 34s         NaN
# 3918  ...         NaN         NaN   2j 10h 45min 29s         NaN
# 3919  ...         NaN         NaN   4j 15h 23min 04s         NaN
# 3920  ...         NaN         NaN   6j 22h 39min 39s         NaN
# 3921  ...         NaN         NaN   9j 15h 11min 12s         NaN
# 3922  ...         NaN         NaN   9j 23h 01min 16s         NaN
# 3923  ...         NaN         NaN  14j 14h 51min 20s         NaN
# 3924  ...         NaN         NaN  14j 17h 48min 10s         NaN
# 3925  ...         NaN         NaN  15j 02h 25min 10s         NaN
# 3926  ...         NaN         NaN  15j 04h 31min 14s         NaN
# 3927  ...         NaN         NaN  15j 07h 52min 44s         NaN
# 3928  ...         NaN         NaN  17j 02h 42min 17s         NaN
# 3929  ...         NaN         NaN  19j 16h 23min 45s         NaN
# 3930  ...         NaN         NaN  21j 05h 12min 05s         NaN
#
#            Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0                  NaN    12.6 kts  24365.7 nm     117.3 %    14.8 kts
# 1        02h 31min 01s    12.6 kts  24365.7 nm     119.6 %    15.1 kts
# 2        04h 09min 25s    12.6 kts  24365.7 nm     117.6 %    14.8 kts
# 3        03h 19min 43s    12.5 kts  24365.7 nm     112.9 %    14.1 kts
# 4        01h 14min 50s    12.6 kts  24365.7 nm     116.8 %    14.7 kts
# 5            22min 16s    12.6 kts  24365.7 nm     119.7 %    15.1 kts
# 6        06h 36min 19s    12.5 kts  24365.7 nm     112.9 %    14.2 kts
# 7            44min 00s    12.5 kts  24365.7 nm     116.9 %    14.7 kts
# 8        21h 03min 00s    12.4 kts  24365.7 nm     114.2 %    14.2 kts
# 9                  NaN    12.6 kts  24365.7 nm     117.3 %    14.8 kts
# 10       02h 31min 01s    12.6 kts  24365.7 nm     119.6 %    15.1 kts
# 11       04h 09min 25s    12.6 kts  24365.7 nm     117.6 %    14.8 kts
# 12       03h 19min 43s    12.5 kts  24365.7 nm     112.9 %    14.1 kts
# 13       01h 14min 50s    12.6 kts  24365.7 nm     116.8 %    14.7 kts
# 14           22min 16s    12.6 kts  24365.7 nm     119.7 %    15.1 kts
# 15       06h 36min 19s    12.5 kts  24365.7 nm     112.9 %    14.2 kts
# 16           44min 00s    12.5 kts  24365.7 nm     116.9 %    14.7 kts
# 17       21h 03min 00s    12.4 kts  24365.7 nm     114.2 %    14.2 kts
# 18       18h 44min 55s    12.3 kts  24365.7 nm     112.2 %    13.8 kts
# 19    2j 02h 37min 35s    12.0 kts  24365.7 nm     116.2 %    13.9 kts
# 20                 NaN    12.6 kts  24365.7 nm     117.3 %    14.8 kts
# 21       02h 31min 01s    12.6 kts  24365.7 nm     119.6 %    15.1 kts
# 22       04h 09min 25s    12.6 kts  24365.7 nm     117.6 %    14.8 kts
# 23       03h 19min 43s    12.5 kts  24365.7 nm     112.9 %    14.1 kts
# 24       01h 14min 50s    12.6 kts  24365.7 nm     116.8 %    14.7 kts
# 25           22min 16s    12.6 kts  24365.7 nm     119.7 %    15.1 kts
# 26       06h 36min 19s    12.5 kts  24365.7 nm     112.9 %    14.2 kts
# 27           44min 00s    12.5 kts  24365.7 nm     116.9 %    14.7 kts
# 28       21h 03min 00s    12.4 kts  24365.7 nm     114.2 %    14.2 kts
# 29       18h 44min 55s    12.3 kts  24365.7 nm     112.2 %    13.8 kts
# ...                ...         ...         ...         ...         ...
# 3901     03h 19min 43s    12.5 kts  24365.7 nm     112.9 %    14.1 kts
# 3902     01h 14min 50s    12.6 kts  24365.7 nm     116.8 %    14.7 kts
# 3903         22min 16s    12.6 kts  24365.7 nm     119.7 %    15.1 kts
# 3904     06h 36min 19s    12.5 kts  24365.7 nm     112.9 %    14.2 kts
# 3905         44min 00s    12.5 kts  24365.7 nm     116.9 %    14.7 kts
# 3906     21h 03min 00s    12.4 kts  24365.7 nm     114.2 %    14.2 kts
# 3907     18h 44min 55s    12.3 kts  24365.7 nm     112.2 %    13.8 kts
# 3908  2j 02h 37min 35s    12.0 kts  24365.7 nm     116.2 %    13.9 kts
# 3909               NaN    12.6 kts  24365.7 nm     117.3 %    14.8 kts
# 3910     02h 31min 01s    12.6 kts  24365.7 nm     119.6 %    15.1 kts
# 3911     04h 09min 25s    12.6 kts  24365.7 nm     117.6 %    14.8 kts
# 3912     03h 19min 43s    12.5 kts  24365.7 nm     112.9 %    14.1 kts
# 3913     01h 14min 50s    12.6 kts  24365.7 nm     116.8 %    14.7 kts
# 3914         22min 16s    12.6 kts  24365.7 nm     119.7 %    15.1 kts
# 3915     06h 36min 19s    12.5 kts  24365.7 nm     112.9 %    14.2 kts
# 3916         44min 00s    12.5 kts  24365.7 nm     116.9 %    14.7 kts
# 3917     21h 03min 00s    12.4 kts  24365.7 nm     114.2 %    14.2 kts
# 3918     18h 44min 55s    12.3 kts  24365.7 nm     112.2 %    13.8 kts
# 3919  2j 04h 37min 35s    12.0 kts  24365.7 nm     116.2 %    13.9 kts
# 3920  2j 07h 16min 35s    11.7 kts  24365.7 nm     113.7 %    13.2 kts
# 3921  2j 16h 31min 33s    11.3 kts  24365.7 nm     122.0 %    13.8 kts
# 3922     07h 50min 04s    11.3 kts  24365.7 nm     113.3 %    12.8 kts
# 3923  4j 15h 50min 04s    10.7 kts  24365.7 nm     116.8 %    12.5 kts
# 3924     02h 56min 50s    10.7 kts  24365.7 nm     119.3 %    12.8 kts
# 3925     08h 37min 00s    10.7 kts  24365.7 nm     117.4 %    12.5 kts
# 3926     02h 06min 04s    10.6 kts  24365.7 nm     117.6 %    12.5 kts
# 3927     03h 21min 30s    10.6 kts  24365.7 nm     114.8 %    12.2 kts
# 3928  1j 18h 49min 33s    10.4 kts  24365.7 nm     115.6 %    12.1 kts
# 3929  2j 13h 41min 28s    10.2 kts  24365.7 nm     115.5 %    11.7 kts
# 3930  1j 12h 48min 20s    10.0 kts  24365.7 nm     113.5 %    11.4 kts
#
#      Unnamed: 20
# 0     28583.8 nm
# 1     29135.0 nm
# 2     28650.0 nm
# 3     27501.5 nm
# 4     28448.5 nm
# 5     29175.5 nm
# 6     27512.3 nm
# 7     28489.9 nm
# 8     27832.5 nm
# 9     28583.8 nm
# 10    29135.0 nm
# 11    28650.0 nm
# 12    27501.5 nm
# 13    28448.5 nm
# 14    29175.5 nm
# 15    27512.3 nm
# 16    28489.9 nm
# 17    27832.5 nm
# 18    27346.9 nm
# 19    28315.2 nm
# 20    28583.8 nm
# 21    29135.0 nm
# 22    28650.0 nm
# 23    27501.5 nm
# 24    28448.5 nm
# 25    29175.5 nm
# 26    27512.3 nm
# 27    28489.9 nm
# 28    27832.5 nm
# 29    27346.9 nm
# ...          ...
# 3901  27501.5 nm
# 3902  28448.5 nm
# 3903  29175.5 nm
# 3904  27512.3 nm
# 3905  28489.9 nm
# 3906  27832.5 nm
# 3907  27346.9 nm
# 3908  28315.2 nm
# 3909  28583.8 nm
# 3910  29135.0 nm
# 3911  28650.0 nm
# 3912  27501.5 nm
# 3913  28448.5 nm
# 3914  29175.5 nm
# 3915  27512.3 nm
# 3916  28489.9 nm
# 3917  27832.5 nm
# 3918  27346.9 nm
# 3919  28315.2 nm
# 3920  27697.1 nm
# 3921  29728.5 nm
# 3922  27597.0 nm
# 3923  28456.7 nm
# 3924  29067.7 nm
# 3925  28603.3 nm
# 3926  28663.5 nm
# 3927  27976.9 nm
# 3928  28172.7 nm
# 3929  28137.8 nm
# 3930  27656.2 nm
#
# [3931 rows x 22 columns]

# %% [raw]
# Pour les étapes suivantes, nous utiliserons les données de classement juste avant les arrivées des voiliers, c'est à dire le dataframe: rankings_data_skippers_not_arrived

# %% [markdown]
# ### Acquisition des caractéristiques des bateaux

# %%
### extract boats characteristics

# Define a function to extract boats characteristics
def Boats_characteristics(url="https://www.vendeeglobe.org/fr/glossaire"):
    
    List_boats_charact = []

    req = requests.get(url) # make request

    soup = BeautifulSoup(req.content) # extract all information

    # extract specific information
    boats_infos = soup.find_all('div', class_='boats-list__infos')
    boats_name = [info.find('h3').text.strip() for info in boats_infos]
    skippers_name = [info.find('span').text.strip() for info in boats_infos]
    
    boats_pop_infos = soup.find_all('div', class_='boats-list__popup-infos')
    for i, info in enumerate(boats_pop_infos):
        pop_boats_infos = info.find_all('li')

        # Retrieve the boat characteristics
        characteristics = [tuple(characteristics.text.split(' : ', maxsplit=1)) for characteristics in pop_boats_infos]
        characteristics = dict(map(reversed, characteristics))
        characteristics = {j: k for k, j in characteristics.items()}
        other_characteristics = dict(XNom_skipper=skippers_name[i], XNom_bateau=boats_name[i])
        other_characteristics.update(characteristics)
        List_boats_charact.append(other_characteristics)

    boats_characteristics = pd.DataFrame(List_boats_charact)
    return boats_characteristics


# Apply function to extract boats characteristics data
boats_characteristics = Boats_characteristics()

# Save extract data to csv file in local folder
boat_data_dir = 'data/' + 'boat_data/' # folder name
if not os.path.exists(boat_data_dir):
        os.makedirs(boat_data_dir)     # Create folder if not exit
file = boat_data_dir + 'boats_characteristics.csv' # define a destination file name and a path
boats_characteristics.to_csv(file, index=False)  
#boats_characteristics = pd.read_csv(file)

boats_characteristics
# Out:
#                                Anciens noms du bateau  \
# 0                      No Way Back, Vento di Sardegna
# 1            Gitana Eighty, Synerciel, Newrest-Matmut
# 2   Famille Mary-Etamine du Lys, Initiatives Coeur...
# 3                       Safran 2 - Des Voiles et Vous
# 4                                                 NaN
# 5   Ecover3, Président, Gamesa, Kilcullen Voyager-...
# 6                               Banque Populaire VIII
# 7   Kingfisher - Educacion sin Fronteras - Forum M...
# 8   Paprec-Virbac2, Estrella Damm, We are Water, L...
# 9                                         Macif - SMA
# 10                                                NaN
# 11       Maître CoQ - Banque Populaire VII- Foncia II
# 12              Foresight Natural Energy, Maisonneuve
# 13  Spirit of Yukoh, Neutrogena, Hugo Boss, Estrel...
# 14                                                NaN
# 15  Delta Dore, Bureau Vallée, Vers un Monde sans ...
# 16                                                NaN
# 17               Armor Lux, We Are Water, La Fabrique
# 18  Edmond de Rothschild, Malizia - Yacht Club de ...
# 19                      Aviva, GAES Centros Auditivos
# 20                                  Quéguiner, Safran
# 21  Cheminées Poujoulat, Mare, Maître CoQ, Mapfre,...
# 22  Hugo Boss, Energa, Compagnie du Lit-Boulogne B...
# 23                Great America IV, Mirabaud, Temenos
# 24                              Saint-Michel - Virbac
# 25         Brit Air, Votre Nom autour du Monde, MACSF
# 26                                                NaN
# 27                          Comme Un Seul Homme, DCNS
# 28                                                NaN
# 29                                                NaN
# 30                     Le Souffle du Nord, Groupe Bel
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
#
#                                          Architecte  \
# 0                                      VPLP/Verdier
# 1                                 Bruce Farr Design
# 2                                      Marc Lombard
# 3                                    Verdier - VPLP
# 4                                              VPLP
# 5              Owen Clarke Design LLP - Clay Oliver
# 6                                    Verdier - VPLP
# 7                                Owen Clarke Design
# 8                           Bruce Farr Yacht Design
# 9                                    Verdier - VPLP
# 10                                          Verdier
# 11                                   VPLP - Verdier
# 12                                          Lavanos
# 13                                Bruce Farr Design
# 14                                   Verdier - VPLP
# 15                                Bruce Farr design
# 16                                              NaN
# 17                                   Pierre Rolland
# 18                                   Verdier - VPLP
# 19                               Owen Clarke Design
# 20                                   Verdier - VPLP
# 21                                Bruce Farr design
# 22                                Finot-Conq Design
# 23                                      Owen Clarke
# 24                                   VPLP - Verdier
# 25                                Groupe Finot-Conq
# 26                                          Verdier
# 27                                Groupe Finot-Conq
# 28                                             VPLP
# 29                                Juan Kouyoumdjian
# 30                                   Verdier - VPLP
# 31  VPLP - Alex Thomson Racing (led by Pete Hobson)
# 32                                   Samuel Manuard
# 33                                Juan Kouyoumdjian
#
#                                              Chantier  Date de lancement  \
# 0                                      Persico Marine       01 Août 2015
# 1            Southern Ocean Marine (Nouvelle Zélande)       08 Mars 2007
# 2                                          MAG France       01 Mars 1998
# 3                                    CDK Technologies       12 Mars 2015
# 4                                    CDK Technologies       18 Août 2018
# 5                           Hakes Marine - Mer Agitée       03 Août 2007
# 6                                    CDK Technologies       09 Juin 2015
# 7                                      Martens Yachts    02 Février 2000
# 8            Southern Ocean Marine (Nouvelle-Zélande)    02 Février 2007
# 9                                    CDK - Mer Agitée       01 Mars 2011
# 10                      CDK technologies - MerConcept       05 Août 2019
# 11                                   CDK Technologies  20 Septembre 2010
# 12                                   Artech do Brasil    15 Janvier 2005
# 13                         Offshore Challenge - Cowes    03 Juillet 2007
# 14                                   CDK Technologies       08 Mars 2010
# 15                                      JMV Cherbourg    26 Juillet 2006
# 16                                                NaN    01 Janvier 1970
# 17                                      Bernard Stamm    03 Juillet 1999
# 18                                         Multiplast       07 Août 2015
# 19       Hakes Marine - Wellington (Nouvelle-Zélande)       06 Août 2007
# 20                           Chantier Naval de Larros    04 Juillet 2007
# 21                                   CDK Technologies    03 Janvier 2007
# 22                                     Neville Hutton       01 Juin 2007
# 23                    Southern Ocean Marine, Tauranga        04 Mai 2006
# 24                                         Multiplast      02 Avril 2015
# 25                                         Multiplast       01 Août 2007
# 26                                            Persico  03 Septembre 2019
# 27                                         Multiplast       10 Août 2008
# 28                                         Multiplast  05 Septembre 2019
# 29  CDK Technologies / Assemblage : Team ARKEA PAPREC    19 Juillet 2019
# 30                Indiana Yachting (Scarlino, Italie)  07 Septembre 2007
# 31                                   Carrington Boats       15 Août 2019
# 32                                      Black Pepper©    31 Janvier 2020
# 33                      CDK technologies - Mer Agitée        15 Mai 2020
#
#    Déplacement (poids) Hauteur mât Largeur Longueur Nombre de dérives  \
# 0                  7 t        29 m  5,85 m  18,28 m             foils
# 1                   9t         28m   5,80m   18,28m                 2
# 2                   9t        29 m   5,54m   18,28m                 2
# 3                  8 t        29 m  5,80 m  18,28 m             foils
# 4                   8t        29 m  5,85 m  18,28 m             foils
# 5           7,9 tonnes        29 m  5,65 m  18,28 m             foils
# 6                7,6 t       28 m   5,80 m  18,28 m             foils
# 7                8,9 t        26 m  5,30 m  18,28 m                 2
# 8                  9 t       28,50  5,80 m  18,28 m    2 asymétriques
# 9                7,7 t        29 m  5,70 m  18,28 m                 2
# 10                 8 t        29 m  5,85 m  18,28 m             foils
# 11               7,8 t        27 m  5,70 m  18,28 m             foils
# 12               8,5 t        29 m  5,60 m  18,28 m                 2
# 13                 8 t        29 m  5,85 m  18,28 m                 2
# 14                  NC     27,40 m  5,50 m  18,28 m             foils
# 15               8,5 t        29 m  5,75 m  18,28 m                 2
# 16                 NaN         NaN     NaN      NaN               NaN
# 17                 9 t        29 m  5,70 m  18,28 m                 2
# 18               7,6 t        29 m  5,70 m  18,28 m             foils
# 19               8,5 t        28 m  5,80 m  18,28 m                 2
# 20               7,7 t        27 m  5,60 m  18,28 m             foils
# 21                 8 t        28 m  5,90 m  18,28 m                 2
# 22               8,5 t        28 m  5,84 m  18,28 m             foils
# 23               8,5 t        28 m  5,50 m  18,28 m                 2
# 24                 8 t        29 m  5,80 m  18,28 m             foils
# 25                  nc        27 m  5,90 m  18,28 m             foils
# 26                 8 t        29 m  5,85 m  18,28 m             foils
# 27               8,5 t        29 m  5,85 m  18,28 m                 2
# 28                 8 t        29 m  5,85 m  18,28 m             foils
# 29                 8 t        29 m  5,70 m  18,28 m            foiler
# 30               7,7 t        29 m  5,50 m  18,28 m                 2
# 31               7,7 t        29 m  5,40 m  18,28 m             foils
# 32               7,8 t        28 m  5,50 m  18,28 m             foils
# 33               7,9 t     27,30 m  5,70 m  18,28 m             foils
#
#    Numéro de voile Surface de voiles au portant Surface de voiles au près  \
# 0           FRA 56                       570 m2                    320 m2
# 1           FRA 49                       560 m2                    280 m2
# 2            FRA72                       580 m2                    260 m2
# 3               17                       550 m2                    310 m2
# 4               08                       600 m2                    320 m2
# 5           FRA 14                       610 m²                    300 m²
# 6               18                       600 m2                    300 m2
# 7           ESP 33                       470 m2                    240 m2
# 8           FRA 71                       560 m2                    270 m2
# 9            FRA30                       570 m2                    340 m2
# 10          FRA 79                       560 m2                    350 m2
# 11          FRA109                       600 m2                    300 m2
# 12              69                       650 m2                    250 m2
# 13           FRA09                       700 m2                    300 m2
# 14          FRA 85                       600 m2                    300 m2
# 15           FRA83                       620 m2                    300 m2
# 16             NaN                          NaN                       NaN
# 17           GBR77                       580 m2                    300 m2
# 18              16                       490 m2                    290 m2
# 19          FIN222                       580 m2                    270 m2
# 20          FRA 27                       650 m2                    300 m2
# 21             001                       620 m2                    300 m2
# 22          FRA 92                       550 m2                    300 m2
# 23           FRA50                       600 m2                    330 m2
# 24          ITA 34                       600 m2                    300 m2
# 25           SUI07                       580 m2                    290 m2
# 26             NaN                       560 m2                    350 m2
# 27         FRA1000                       610 m2                    350 m2
# 28          JPN 11                       580 m2                    320 m2
# 29               4                       600 m2                    260 m2
# 30           FRA53                       700 m2                    365 m2
# 31          GBR 99                       630 m2                    330 m2
# 32               2                       535 m2                    270 m2
# 33           FRA 6                       535 m2                    270 m2
#
#    Tirant d'eau                      Voile quille  \
# 0        4,50 m                          monotype
# 1         4,50m                       acier forgé
# 2         4,50m                             acier
# 3        4,50 m                acier mécano soudé
# 4        4,50 m                             acier
# 5        4,50 m             basculante avec vérin
# 6        4,50 m                             acier
# 7        4,50 m                             acier
# 8        4,50 m  basculante sur vérin hydraulique
# 9         4,5 m                       acier forgé
# 10       4,50 m                             acier
# 11       4,50 m                       acier forgé
# 12       4,50 m                             acier
# 13       4,50 m                       acier forgé
# 14       4,50 m                Acier mécano soudé
# 15       4,50 m                       acier forgé
# 16          NaN                               NaN
# 17       4,50 m                           carbone
# 18       4,50 m                             acier
# 19       4,50 m                             acier
# 20       4,50 m                             acier
# 21       4,50 m                       acier forgé
# 22       4,50 m                          monotype
# 23       4,50 m                           carbone
# 24        4,5 m                       acier forgé
# 25       4,50 m                           carbone
# 26       4,50 m                       acier forgé
# 27       4,50 m                       acier forgé
# 28       4,50 m                       acier forgé
# 29       4,50 m                        Inox usiné
# 30       4,50 m                             acier
# 31       4,50 m                       acier forgé
# 32       4,50 m                       acier forgé
# 33       4,50 m                               NaN
#
#                            XNom_bateau          XNom_skipper
# 0             NEWREST - ART & FENÊTRES        Fabrice AMEDEO
# 1                 PURE - Best Western®      Romain ATTANASIO
# 2                     TSE -  4MYPLANET        Alexia BARRIER
# 3                        Maître CoQ IV      Yannick BESTAVEN
# 4                               CHARAL         Jérémie BEYOU
# 5    LA MIE CÂLINE - ARTISANS ARTIPÔLE     Arnaud BOISSIÈRES
# 6                      BUREAU VALLEE 2          Louis BURTON
# 7                 ONE PLANET ONE OCEAN           Didac COSTA
# 8                         GROUPE SÉTIN         Manuel COUSIN
# 9                   BANQUE POPULAIRE X       Clarisse CREMER
# 10                              APIVIA         Charlie DALIN
# 11                   INITIATIVES-COEUR            Sam DAVIES
# 12                               MERCI   Sébastien DESTREMAU
# 13                 OMIA - WATER FAMILY      Benjamin DUTREUX
# 14                                 PRB       Kevin ESCOFFIER
# 15           Compagnie du Lit / Jiliti        Clément GIRAUD
# 16                                         François Guiffant
# 17                            MEDALLIA              Pip HARE
# 18  SEAEXPLORER - YACHT CLUB DE MONACO        Boris HERRMANN
# 19                               STARK           Ari HUUSELA
# 20                               MACSF      Isabelle JOSCHKE
# 21                         Yes We Cam!           Jean LE CAM
# 22                     TIME FOR OCEANS  Stéphane LE DIRAISON
# 23                  CAMPAGNE DE FRANCE        Miranda MERRON
# 24                      PRYSMIAN GROUP      Giancarlo PEDOTE
# 25                         LA FABRIQUE           Alan  ROURA
# 26                           LinkedOut         Thomas RUYANT
# 27                       GROUPE APICIL         Damien SEGUIN
# 28                 DMG MORI Global One      Kojiro SHIRAISHI
# 29                        ARKEA PAPREC       Sébastien SIMON
# 30                     V and B-MAYENNE          Maxime SOREL
# 31                           HUGO BOSS          Alex THOMSON
# 32              L'OCCITANE EN PROVENCE          Armel TRIPON
# 33                     CORUM L'EPARGNE      Nicolas TROUSSEL

# %% [markdown]
# ## 2. Préparation des données

# %% [markdown]
# ### Préparation des données relatives aux classements

# %% [raw]
# Nous utiliserons les données de classement juste avant les arrivées des voiliers, c'est à dire le dataframe: rankings_data_skippers_not_arrived

# %%
# preprocessing of data

df = rankings_data_skippers_not_arrived.copy()

df.rename(columns = {'Unnamed: 1':'Rang','Unnamed: 2':'Voile','Unnamed: 3':'Bateau',\
                            'Unnamed: 4':'Heure FR','Unnamed: 5':'Latitude','Unnamed: 6':'Longitude',\
                            'Unnamed: 7':'Cap30m (°)','Unnamed: 8':'Vitesse30m (kts)','Unnamed: 9':'VMG30m (kts)',\
                            'Unnamed: 10':'Distance30m (mètre)','Unnamed: 11':'Cap (°)','Unnamed: 12':'Vitesse (kts)',\
                            'Unnamed: 13':'VMG (kts)','Unnamed: 14':'Distance (mètre)','Unnamed: 15':'Cap24h (°)',\
                            'Unnamed: 16':'Vitesse24h (kts)','Unnamed: 17':'VMG24h (kts)','Unnamed: 18':'Distance24h (mètre)',\
                            'Unnamed: 19':'DFT (nm)','Unnamed: 20':'DTL (nm)'}, inplace = True)
    
df = df.drop(columns = ["skipper_status"])
    
df['Rang'] = df['Rang'].apply(lambda x: '-1' if x == 'RET' else x)
    
df['Voile'] = df['Voile'].fillna("")
nat = df['Voile'].apply(lambda x: x.split(' ')[0])
nat = nat.apply(lambda x: x.split('\n')[1])
ch = df['Voile'].apply(lambda x: x.split(' ')[1])
df.insert(2, 'Nationalité', nat)
df.insert(3, 'Numéro du bateau', ch)
df = df.drop(columns = ["Voile"])
    
df['Bateau'] = df['Bateau'].fillna("")
names = list(df['Bateau']) 
prenom, nom, architecte = [],[], []
for i, name in enumerate(names):
    temp, temp_archi = name.split('\n')
    architecte.append(temp_archi)
    if len(temp.split())==2:
        prenom.append(temp.split()[0])
        nom.append(temp.split()[1])
    else:
        prenom.append(temp.split()[0])
        a,b = temp.split()[1:3]
        nom.append(a +' '+b)
df.insert(2, 'Nom', nom)
df['Nom'] = df['Nom'].str.upper()
df.insert(3, 'Prenom', prenom)
df.insert(6, 'Architecte', architecte)
df = df.drop(columns = ["Bateau"])
    

liste_cap =['Cap30m (°)', 'Cap (°)', 'Cap24h (°)']
for j,col in enumerate(liste_cap):
    df[col] = df[col].fillna('')
    df[col] =df[col].apply(lambda x: str(x)[:-1])   
liste_vitesse = ['Vitesse30m (kts)', 'VMG30m (kts)','Vitesse (kts)', 'VMG (kts)','Vitesse24h (kts)', 'VMG24h (kts)']
for j,col in enumerate(liste_vitesse):
    df[col] = df[col].fillna('')
    df[col] =df[col].apply(lambda x: str(x)[:-3])  
liste_nm = ['Distance30m (mètre)','Distance (mètre)','Distance24h (mètre)','DFT (nm)','DTL (nm)']
for j,col in enumerate(liste_nm):
    df[col] = df[col].fillna('')
    df[col] =df[col].apply(lambda x: str(x)[:-2])  

df['Heure FR'] = df['Heure FR'].apply(lambda x: datetime.datetime.strptime(x.split(' FR')[0], '%H:%M').strftime('%H:%M:%S') if isinstance(x, str) else np.nan)


process_rankings_data_skippers_not_arrived = df.copy()

process_rankings_data_skippers_not_arrived.head()
# Out:
#             date_time Rang        Nom    Prenom Nationalité Numéro du bateau  \
# 0 2021-01-29 18:00:00   10      SOREL    Maxime         FRA               53
# 1 2021-01-29 18:00:00   11     TRIPON     Armel         FRA               02
# 2 2021-01-29 18:00:00   12     CREMER  Clarisse         FRA               30
# 3 2021-01-29 18:00:00   13  ATTANASIO    Romain         FRA               49
# 4 2021-01-29 18:00:00   14      BEYOU   Jérémie         FRA                8
#
#                                Architecte  Heure FR    Latitude   Longitude  \
# 0                         V And B Mayenne  17:30:00  46°07.29'N  06°13.58'W
# 1                  L'Occitane en Provence  17:30:00  41°40.31'N  10°38.49'W
# 2                      Banque Populaire X  17:30:00  36°26.28'N  29°36.29'W
# 3  Pure - Best Western Hotels and Resorts  17:30:00  23°59.68'N  34°28.19'W
# 4                                  Charal  17:30:00  22°51.11'N  36°30.29'W
#
#    ... Cap (°) Vitesse (kts) VMG (kts) Distance (mètre) Cap24h (°)  \
# 0  ...      72         15.1      15.0             45.3          49
# 1  ...      17          7.5       7.3             22.4          62
# 2  ...       9          8.7       6.1             26.2          10
# 3  ...      18         10.8      10.0             32.5          11
# 4  ...       2         15.2      12.0             45.6         356
#
#   Vitesse24h (kts) VMG24h (kts) Distance24h (mètre) DFT (nm) DTL (nm)
# 0            12.4         12.3               298.4    185.1      0.0
# 1             7.3          7.1               175.1    482.6    297.5
# 2            11.9          9.3               285.5   1379.1   1194.0
# 3            11.3         10.2               271.9   2069.2   1884.1
# 4            16.7         12.9               400.0   2194.6   2009.5
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Extraction des caractéristiques techniques de chacun des voiliers

# %%
# change name format of month
def change_format_date(date):
    modif_month = dict(janvier=1, fevrier=2, mars=3, avril=4, mai=5, juin=6, juillet=7, aout=8, septembre=9, octobre=10, novembre=11, decembre=12)
    day, month, year = tuple(date.split())
    month = modif_month[unidecode(month).lower()]
    return datetime.datetime(int(year), int(month), int(day))

df = boats_characteristics.copy()

# # preprocessing of data

df['Nom bateau'] = df['XNom_bateau']
df['Date de lancement'] = df['Date de lancement'].apply(lambda x: change_format_date(x))

#liste = ['Longueur', 'Largeur', "Tirant d'eau",'Déplacement (poids)', 'Hauteur mât', 'Surface de voiles au près', 'Surface de voiles au portant']
#
df['Longueur'] = df['Longueur'].apply(lambda x: float(re.sub(r"([^0-9,]+)",'', x).replace(',', '.')) if (isinstance(x, str) and any([l.isdigit() for l in x])) else np.nan)
df['Largeur'] = df['Largeur'].apply(lambda x: float(re.sub(r"([^0-9,]+)",'', x).replace(',', '.')) if (isinstance(x, str) and any([l.isdigit() for l in x])) else np.nan)
df["Tirant d'eau"] = df["Tirant d'eau"].apply(lambda x: float(re.sub(r"([^0-9,]+)",'', x).replace(',', '.')) if (isinstance(x, str) and any([l.isdigit() for l in x])) else np.nan)
df['Déplacement (poids)'] = df['Déplacement (poids)'].apply(lambda x: float(re.sub(r"([^0-9,]+)",'', x).replace(',', '.')) if (isinstance(x, str) and any([l.isdigit() for l in x])) else np.nan)
df['Hauteur mât'] = df['Hauteur mât'].apply(lambda x: float(re.sub(r"([^0-9,]+)",'', x).replace(',', '.')) if (isinstance(x, str) and any([l.isdigit() for l in x])) else np.nan)
df['Surface de voiles au près'] = df['Surface de voiles au près'].apply(lambda x: float(x[:3]) if (isinstance(x, str) and len(x)>3) else np.nan)
df['Surface de voiles au portant'] = df['Surface de voiles au portant'].apply(lambda x: float(x[:3]) if (isinstance(x, str) and len(x)>3) else np.nan)

# 
drift_amount2no = {drift_amount:no for no, drift_amount in enumerate(df['Nombre de dérives'].dropna().unique().tolist())}
no2drift_amounts = {v:k for k,v in drift_amount2no.items()}
df['Nombre de dérives'] = df['Nombre de dérives'].apply(lambda x: drift_amount2no[x] if isinstance(x, str) else np.nan)

#
keel2no = {keel:no for no, keel in enumerate(df['Voile quille'].dropna().unique().tolist())}
no2keels = {v:k for k,v in keel2no.items()}
df['Voile quille'] = df['Voile quille'].apply(lambda x: keel2no[x] if isinstance(x, str) else np.nan)

# split variables
df['Prenom'] = df['XNom_skipper'].apply(lambda x: ''.join([word for word in x.split() if not word.isupper()]))
df['Nom'] = df['XNom_skipper'].apply(lambda x: unidecode(''.join([word for word in x.split() if word.isupper()])))
df['Numéro de voile'] = df['Numéro de voile'].apply(lambda x: ' '.join([x[:3], x[3:]]) if (isinstance(x, str) and (len(x) > 3)) else x)
df['Nationalité'] = df['Numéro de voile'].apply(lambda x: ''.join([l for l in x if (l.lower().isalpha())]) if isinstance(x, str) else np.nan)
df['Numéro du bateau'] = df['Numéro de voile'].apply(lambda x: ''.join([l for l in x if l.isdigit()]) if isinstance(x, str) else np.nan)
df = df.drop(columns=['XNom_bateau', 'XNom_skipper', 'Numéro de voile'])
df = df.reindex(columns=(['Nom', 'Prenom', 'Nationalité', 'Numéro du bateau', 'Nom bateau'] + list([col for col in df.columns if col not in ['Nom', 'Prenom', 'Nationalité', 'Numéro du bateau', 'Nom bateau']])))

process_boats_characteristics = df.copy()

process_boats_characteristics.head()
# Out:
#          Nom   Prenom Nationalité Numéro du bateau                Nom bateau  \
# 0     AMEDEO  Fabrice         FRA               56  NEWREST - ART & FENÊTRES
# 1  ATTANASIO   Romain         FRA               49      PURE - Best Western®
# 2    BARRIER   Alexia         FRA               72          TSE -  4MYPLANET
# 3   BESTAVEN  Yannick                           17             Maître CoQ IV
# 4      BEYOU  Jérémie                           08                    CHARAL
#
#                               Anciens noms du bateau         Architecte  \
# 0                     No Way Back, Vento di Sardegna       VPLP/Verdier
# 1           Gitana Eighty, Synerciel, Newrest-Matmut  Bruce Farr Design
# 2  Famille Mary-Etamine du Lys, Initiatives Coeur...       Marc Lombard
# 3                      Safran 2 - Des Voiles et Vous     Verdier - VPLP
# 4                                                NaN               VPLP
#
#                                    Chantier Date de lancement  \
# 0                            Persico Marine        2015-08-01
# 1  Southern Ocean Marine (Nouvelle Zélande)        2007-03-08
# 2                                MAG France        1998-03-01
# 3                          CDK Technologies        2015-03-12
# 4                          CDK Technologies        2018-08-18
#
#    Déplacement (poids)  Hauteur mât  Largeur  Longueur  Nombre de dérives  \
# 0                  7.0         29.0     5.85     18.28                0.0
# 1                  9.0         28.0     5.80     18.28                1.0
# 2                  9.0         29.0     5.54     18.28                1.0
# 3                  8.0         29.0     5.80     18.28                0.0
# 4                  8.0         29.0     5.85     18.28                0.0
#
#    Surface de voiles au portant  Surface de voiles au près  Tirant d'eau  \
# 0                         570.0                      320.0           4.5
# 1                         560.0                      280.0           4.5
# 2                         580.0                      260.0           4.5
# 3                         550.0                      310.0           4.5
# 4                         600.0                      320.0           4.5
#
#    Voile quille
# 0           0.0
# 1           1.0
# 2           2.0
# 3           3.0
# 4           2.0

# %% [markdown]
# ### Rapprochement des données des voiliers avec celle des classements

# %%
# drop duplicates columns (in two dataframes) in one dataframe
boats_without_some_variables = process_boats_characteristics.drop(columns=['Prenom','Nationalité','Numéro du bateau', 'Architecte'])

# merge two dataframes
skippers_and_boats = pd.merge(process_rankings_data_skippers_not_arrived, boats_without_some_variables, on='Nom', how='inner')

skippers_and_boats.head()
# Out:
#             date_time Rang    Nom  Prenom Nationalité Numéro du bateau  \
# 0 2021-01-29 18:00:00   10  SOREL  Maxime         FRA               53
# 1 2020-11-10 10:00:00    6  SOREL  Maxime         FRA               53
# 2 2020-12-05 22:00:00   11  SOREL  Maxime         FRA               53
# 3 2020-12-10 15:00:00   11  SOREL  Maxime         FRA               53
# 4 2020-11-21 05:00:00   14  SOREL  Maxime         FRA               53
#
#         Architecte  Heure FR    Latitude   Longitude  ... Date de lancement  \
# 0  V And B Mayenne  17:30:00  46°07.29'N  06°13.58'W  ...        2007-09-07
# 1  V And B Mayenne  09:30:00  43°14.58'N  09°17.24'W  ...        2007-09-07
# 2  V And B Mayenne  21:30:00  42°09.28'S  41°23.81'E  ...        2007-09-07
# 3  V And B Mayenne  14:30:00  42°32.05'S  76°33.98'E  ...        2007-09-07
# 4  V And B Mayenne  04:30:00  05°45.50'S  30°30.23'W  ...        2007-09-07
#
#   Déplacement (poids) Hauteur mât Largeur Longueur Nombre de dérives  \
# 0                 7.7        29.0     5.5    18.28               1.0
# 1                 7.7        29.0     5.5    18.28               1.0
# 2                 7.7        29.0     5.5    18.28               1.0
# 3                 7.7        29.0     5.5    18.28               1.0
# 4                 7.7        29.0     5.5    18.28               1.0
#
#   Surface de voiles au portant Surface de voiles au près Tirant d'eau  \
# 0                        700.0                     365.0          4.5
# 1                        700.0                     365.0          4.5
# 2                        700.0                     365.0          4.5
# 3                        700.0                     365.0          4.5
# 4                        700.0                     365.0          4.5
#
#   Voile quille
# 0          2.0
# 1          2.0
# 2          2.0
# 3          2.0
# 4          2.0
#
# [5 rows x 37 columns]

# %%
skippers_and_boats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18169 entries, 0 to 18168
# Data columns (total 37 columns):
# date_time                       18169 non-null datetime64[ns]
# Rang                            18169 non-null object
# Nom                             18169 non-null object
# Prenom                          18169 non-null object
# Nationalité                     18169 non-null object
# Numéro du bateau                18169 non-null object
# Architecte                      18169 non-null object
# Heure FR                        14211 non-null object
# Latitude                        14211 non-null object
# Longitude                       14211 non-null object
# Cap30m (°)                      18169 non-null object
# Vitesse30m (kts)                18169 non-null object
# VMG30m (kts)                    18169 non-null object
# Distance30m (mètre)             18169 non-null object
# Cap (°)                         18169 non-null object
# Vitesse (kts)                   18169 non-null object
# VMG (kts)                       18169 non-null object
# Distance (mètre)                18169 non-null object
# Cap24h (°)                      18169 non-null object
# Vitesse24h (kts)                18169 non-null object
# VMG24h (kts)                    18169 non-null object
# Distance24h (mètre)             18169 non-null object
# DFT (nm)                        18169 non-null object
# DTL (nm)                        18169 non-null object
# Nom bateau                      18169 non-null object
# Anciens noms du bateau          12779 non-null object
# Chantier                        18169 non-null object
# Date de lancement               18169 non-null datetime64[ns]
# Déplacement (poids)             16896 non-null float64
# Hauteur mât                     18169 non-null float64
# Largeur                         18169 non-null float64
# Longueur                        18169 non-null float64
# Nombre de dérives               18169 non-null float64
# Surface de voiles au portant    18169 non-null float64
# Surface de voiles au près       18169 non-null float64
# Tirant d'eau                    18169 non-null float64
# Voile quille                    17467 non-null float64
# dtypes: datetime64[ns](2), float64(9), object(26)
# memory usage: 5.3+ MB
